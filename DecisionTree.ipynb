# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.svm as svm
dataset = pd.read_csv('tooth.CSV')
dataset.head()
# Out:
#    Unnamed: 0   len supp  dose
# 0           1   4.2   VC   0.5
# 1           2  11.5   VC   0.5
# 2           3   7.3   VC   0.5
# 3           4   5.8   VC   0.5
# 4           5   6.4   VC   0.5

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset['supp'] = le.fit_transform(dataset['supp'])
dataset.head(100)
# Out:
#     Unnamed: 0   len  supp  dose
# 0            1   4.2     1   0.5
# 1            2  11.5     1   0.5
# 2            3   7.3     1   0.5
# 3            4   5.8     1   0.5
# 4            5   6.4     1   0.5
# 5            6  10.0     1   0.5
# 6            7  11.2     1   0.5
# 7            8  11.2     1   0.5
# 8            9   5.2     1   0.5
# 9           10   7.0     1   0.5
# 10          11  16.5     1   1.0
# 11          12  16.5     1   1.0
# 12          13  15.2     1   1.0
# 13          14  17.3     1   1.0
# 14          15  22.5     1   1.0
# 15          16  17.3     1   1.0
# 16          17  13.6     1   1.0
# 17          18  14.5     1   1.0
# 18          19  18.8     1   1.0
# 19          20  15.5     1   1.0
# 20          21  23.6     1   2.0
# 21          22  18.5     1   2.0
# 22          23  33.9     1   2.0
# 23          24  25.5     1   2.0
# 24          25  26.4     1   2.0
# 25          26  32.5     1   2.0
# 26          27  26.7     1   2.0
# 27          28  21.5     1   2.0
# 28          29  23.3     1   2.0
# 29          30  29.5     1   2.0
# 30          31  15.2     0   0.5
# 31          32  21.5     0   0.5
# 32          33  17.6     0   0.5
# 33          34   9.7     0   0.5
# 34          35  14.5     0   0.5
# 35          36  10.0     0   0.5
# 36          37   8.2     0   0.5
# 37          38   9.4     0   0.5
# 38          39  16.5     0   0.5
# 39          40   9.7     0   0.5
# 40          41  19.7     0   1.0
# 41          42  23.3     0   1.0
# 42          43  23.6     0   1.0
# 43          44  26.4     0   1.0
# 44          45  20.0     0   1.0
# 45          46  25.2     0   1.0
# 46          47  25.8     0   1.0
# 47          48  21.2     0   1.0
# 48          49  14.5     0   1.0
# 49          50  27.3     0   1.0
# 50          51  25.5     0   2.0
# 51          52  26.4     0   2.0
# 52          53  22.4     0   2.0
# 53          54  24.5     0   2.0
# 54          55  24.8     0   2.0
# 55          56  30.9     0   2.0
# 56          57  26.4     0   2.0
# 57          58  27.3     0   2.0
# 58          59  29.4     0   2.0
# 59          60  23.0     0   2.0

# %%
plt.figure(1)
sns.heatmap(dataset.corr())
plt.title('Correlation On iris Classes')
# Out:
# Text(0.5, 1.0, 'Correlation On iris Classes')

# %%
from sklearn.model_selection import train_test_split
X = dataset.drop(columns = ['supp'])
Y = dataset['supp']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25)
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
classifier = DecisionTreeClassifier()
classifier.fit(X_train, Y_train)
y_pred = classifier.predict(X_test)
print(classification_report(Y_test, y_pred))
print(confusion_matrix(Y_test, y_pred))
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      1.00      1.00         7
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15
#
# [[8 0]
#  [0 7]]
# accuracy is 1.0
